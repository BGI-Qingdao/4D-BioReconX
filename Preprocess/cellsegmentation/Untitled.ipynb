# %% [markdown]
# # Detect cell boundaries based on ssDNA images

# %% [markdown]
# > **_reference:_**
# > [CellProfiler as a Python package](https://github.com/CellProfiler/CellProfiler/wiki/CellProfiler-as-a-Python-package)

# %%
import cv2

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# we have include a demo image file for your testing, you can find with name 'demo.tif'

# %%
image = cv2.imread('./demo.tif')

# %%
plt.imshow(image)
